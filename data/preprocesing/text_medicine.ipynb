# %%
import pandas as pd 

df = pd.read_csv('../csv/medicine_details.csv')
df
# Out:
#                     Title                           Dạng bào chế - biệt dược  \
# 0    Abobotulinum Toxin A                      Bột pha tiêm: Dysport 300 UI.
# 1    Abobotulinum Toxin A                      Bột pha tiêm: Dysport 300 UI.
# 2                Acarbose                  Viên nén: Glucobay 50 mg, 100 mg.
# 3           Acenocoumarol  Viên nén: Sintrom 4 mg; Minisintrom, Aceronko,...
# 4           Acetazolamide                    Viên nén: Acetazolamide 250 mg.
# ..                    ...                                                ...
# 187        Xylometazoline  Bình xịt định liều hoặc dung dịch nhỏ mũi: Otr...
# 188       Zoledronic Acid  Dung dịch truyền: Aclasta 5 mg/100 ml; Bột pha...
# 189              Zolpidem                           Viên nén: Stilnox 10 mg.
# 190              Zopiclon                     Viên nén: Coumadin 2 mg, 5 mg.
# 191              Zopiclon                Viên nén bao phim: Zopistad 7,5 mg.
#
# ...

# %%
df2 = pd.read_csv('../csv/drugbank.csv')
df2.head()
# Out:
# C:\Users\tranl\AppData\Local\Temp\ipykernel_13364\936700138.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('../csv/drugbank.csv')
#    Unnamed: 0         id  images      tenThuoc dotPheDuyet soQuyetDinh  \
# 0           0  GC-215-13      []      EtonciB1          13   33/QÐ-QLD
# 1           1  GC-216-13  [None]      EtonciB6         NaN   33/QÐ-QLD
# 2           2  GC-217-13  [None]    Dodevifort         NaN  129/QÐ-QLD
# 3           3  GC-219-14  [None]   An thần ACP         145  255/QÐ-QLD
# 4           4  GC-220-14  [None]  Bình can ACP         145  255/QÐ-QLD
#
#      pheDuyet  hieuLuc   soDangKy  \
# 0  05/03/2013      NaN  GC-215-13
# 1  05/03/2013      NaN  GC-216-13
# 2  22/05/2013      NaN  GC-217-13
# 3  14/05/2014      NaN  GC-219-14
# 4  14/05/2014      NaN  GC-220-14
#
#                                             hoatChat  ...  nhomThuoc isHide  \
# ...

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'id', 'images', 'tenThuoc', 'dotPheDuyet', 'soQuyetDinh',
#        'pheDuyet', 'hieuLuc', 'soDangKy', 'hoatChat', 'phanLoai', 'nongDo',
#        'taDuoc', 'baoChe', 'dongGoi', 'tieuChuan', 'tuoiTho', 'congTySx',
#        'congTySxCode', 'nuocSx', 'diaChiSx', 'congTyDk', 'nuocDk', 'diaChiDk',
#        'giaKeKhai', 'huongDanSuDung', 'huongDanSuDungBn', 'nhomThuoc',
#        'isHide', 'rate', 'rutSdk', 'rutSdkFile', 'chuY', 'ten', 'meta', 'rows',
#        'state'],
#       dtype='object')

# %%
df3 = df2[['phanLoai', 'nongDo', 'taDuoc', 'baoChe', 'dongGoi', 'tieuChuan', 'tuoiTho', 'congTySx', 'congTySxCode', 'nuocSx', 'diaChiSx', 'congTyDk', 'nuocDk', 'diaChiDk', 'giaKeKhai', 'huongDanSuDung', 'huongDanSuDungBn', 'nhomThuoc']]
df3
# Out:
#                  phanLoai                     nongDo  \
# 0            Thuốc kê đơn                     150 mg
# 1            Thuốc kê đơn                      120mg
# 2            Thuốc kê đơn                 10 mg/2 ml
# 3      Thuốc không kê đơn                        NaN
# 4      Thuốc không kê đơn                 2g; 2g; 1g
# ...                   ...                        ...
# 40940                 NaN                       4,5g
# 40941                 NaN          0,6g; 0,06g; 4,8g
# 40942                 NaN         0,6g; 0,045g; 4,8g
# 40943                 NaN  0,07 ml; 0,35g; 1,75g; 7g
# 40944                 NaN                      0,5mg
#
#                                                   taDuoc  \
# 0      Tinh bột mì, lactose, gelatin, nipagin, nipaso...
# 1      Tinh bột sắn, tinh bột mì, lactose, cellulose ...
# 2      Natri clorid, methylparaben, propylparaben, nư...
# 3                Dưỡng tân an thần, gây ngủ, bổ ngũ tạng
# ...

# %%
data= pd.read_csv('../csv/medical_bank.csv')
data
# Out:
#                  Tên chung quốc tế                      Mã ATC  \
# 0                        Abacavir.                    J05AF06.
# 1                        Acarbose.                    A10BF01.
# 2                      Acebutolol.                    C07AB04.
# 3                   Acenocoumarol.                    B01AA07.
# 4                   Acetazolamide.                    S01EC01.
# ..                             ...                         ...
# 725  Xylometazoline hydrochloride.  R01AA07, R01AB06, S01GA03.
# 726                     Zanamivir.                    J05AH01.
# 727                    Zidovudine.                    J05AF01.
# 728                   Ziprasidone.                    N05AE04.
# 729                      Zolpidem.                    N05CF02.
#
#                                             Loại thuốc  \
# 0    Thuốc kháng retrovirus, nucleosid ức chế enzym...
# 1    Thuốc điều trị đái tháo đường (ức chế alpha gl...
# ...
